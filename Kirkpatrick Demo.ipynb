# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt

import logging

logging.basicConfig(level=logging.INFO)

# %%
import drawing
from kirkpatrick import Kirkpatrick, time_tests
from polygons import Point, Polygon, Triangle
from polygons import generate_random_tiling
from polygons import generate_triangle_tiling

# %load_ext autoreload
# %autoreload 2
# %autoreload

# %matplotlib inline

# %% [markdown]
# # Make a tiling

# %% [markdown]
# ### You can generate a random tiling via the polygons library

# %%
n_tiles = 20
size = 100

# Start with a square and construct the tiling inside
base = Polygon([Point(0, 0), Point(size, 0), Point(size, size), Point(0, size)])

# Iteratively split the polygon randomly 4 times to make tiles 
random_tiles = generate_random_tiling(base, n_iter=n_tiles - 1)

drawing.plot_polygons(random_tiles, 'k-')

# %%
n_pts = 100
size = 1000

triangles = generate_triangle_tiling(num_pts=n_pts, size=size)

drawing.plot_polygons(triangles, 'k-')

# %% [markdown]
# ### Or you can declare your own

# %%
manual_tiles = [
    Polygon([
        Point(8.681595, 3.113523), Point(10.000000, 0.000000), Point(10.000000, 10.000000), 
        Point(1.258842, 6.913277), Point(3.670703, 6.336320), Point(0.000000, 0.000000),  
        Point(8.668625, 6.053702)
    ]), 
    Polygon([
        Point(10.000000, 10.000000), Point(0.000000, 10.000000), Point(0.000000, 0.000000), 
        Point(1.258842, 6.913277)
    ]), 
    Polygon([
        Point(1.258842, 6.913277), Point(0.000000, 0.000000), Point(3.670703, 6.336320)
    ]), 
    Polygon([
        Point(0.000000, 0.000000), Point(8.681595, 3.113523), Point(8.668625, 6.053702)
    ]), 
    Polygon([
        Point(0.000000, 0.000000), Point(10.000000, 0.000000), Point(8.681595, 3.113523)
    ])
]

drawing.plot_polygons(manual_tiles, 'k-')

# %% [markdown]
# # Instantiate the Point Locator

# %%
locator = Kirkpatrick(random_tiles)
# Out:
# dict_items([(Point(-68.508530, -6.220085), {0, 1}), (Point(0.000000, 100.000000), {0, 3}), (Point(168.508530, -6.220085), {1, 2}), (Point(100.000000, 0.000000), {2, 4}), (Point(6.584443, 71.668894), {3, 5}), (Point(15.675366, 3.084451), {4, 5})])
# dict_items([(Point(56.515498, 20.108235), {0, 2}), (Point(100.000000, 0.000000), {0, 1}), (Point(46.296300, 9.321865), {1, 5}), (Point(27.049239, 30.192910), {2, 3}), (Point(6.938260, 70.014234), {3, 4}), (Point(6.584443, 71.668894), {4, 6}), (Point(15.675366, 3.084451), {5, 6})])
# dict_items([(Point(100.000000, 100.000000), {0, 1}), (Point(88.062412, 50.383311), {0, 2}), (Point(98.288708, 10.593515), {1, 2})])
# dict_items([(Point(95.094673, 5.470032), {0, 1}), (Point(74.843715, 20.857048), {0, 7}), (Point(56.515498, 20.108235), {1, 2}), (Point(6.584443, 71.668894), {2, 5}), (Point(63.545406, 54.183765), {3, 4}), (Point(100.000000, 100.000000), {3, 6}), (Point(49.193606, 38.863496), {4, 5}), (Point(88.062412, 50.383311), {6, 7})])
# dict_items([(Point(43.781524, 89.935670), {0, 2}), (Point(79.123816, 87.669076), {0, 1}), (Point(49.193606, 38.863496), {1, 4}), (Point(29.296779, 96.401376), {2, 3}), (Point(100.000000, 100.000000), {3, 4})])
# dict_items([(Point(-68.508530, -6.220085), {0, 1}), (Point(0.000000, 100.000000), {0, 5}), (Point(15.675366, 3.084451), {1, 3}), (Point(6.938260, 70.014234), {2, 3}), (Point(56.515498, 20.108235), {2, 4}), (Point(49.193606, 38.863496), {4, 5})])
# dict_items([(Point(100.000000, 100.000000), {0, 4}), (Point(98.288708, 10.593515), {0, 5}), (Point(74.843715, 20.857048), {1, 7}), (Point(56.515498, 20.108235), {1, 2}), (Point(49.193606, 38.863496), {2, 3}), (Point(63.545406, 54.183765), {3, 4}), (Point(100.000000, 0.000000), {5, 6}), (Point(95.094673, 5.470032), {6, 7})])
# dict_items([(Point(43.781524, 89.935670), {0, 2}), (Point(79.123816, 87.669076), {0, 1}), (Point(100.000000, 100.000000), {1, 4}), (Point(49.193606, 38.863496), {2, 3}), (Point(0.000000, 100.000000), {3, 4})])
# dict_items([(Point(15.675366, 3.084451), {0, 2}), (Point(56.515498, 20.108235), {0, 1}), (Point(6.938260, 70.014234), {1, 2})])
# dict_items([(Point(15.675366, 3.084451), {0, 2}), (Point(100.000000, 0.000000), {0, 1}), (Point(56.515498, 20.108235), {1, 2})])
# dict_items([(Point(98.288708, 10.593515), {0, 1}), (Point(100.000000, 0.000000), {0, 4}), (Point(100.000000, 100.000000), {1, 2}), (Point(74.843715, 20.857048), {2, 3}), (Point(56.515498, 20.108235), {3, 4})])
# dict_items([(Point(0.000000, 100.000000), {0, 2}), (Point(56.515498, 20.108235), {0, 1}), (Point(63.545406, 54.183765), {1, 5}), (Point(43.781524, 89.935670), {2, 4}), (Point(100.000000, 100.000000), {3, 5}), (Point(79.123816, 87.669076), {3, 4})])
# dict_items([(Point(56.515498, 20.108235), {0, 3}), (Point(0.000000, 100.000000), {0, 1}), (Point(-68.508530, -6.220085), {1, 2}), (Point(15.675366, 3.084451), {2, 3})])
# dict_items([(Point(100.000000, 100.000000), {0, 2}), (Point(0.000000, 100.000000), {0, 1}), (Point(43.781524, 89.935670), {1, 3}), (Point(63.545406, 54.183765), {2, 3})])
# dict_items([(Point(100.000000, 0.000000), {0, 7}), (Point(98.288708, 10.593515), {0, 1}), (Point(74.843715, 20.857048), {1, 5}), (Point(43.781524, 89.935670), {2, 3}), (Point(0.000000, 100.000000), {2, 4}), (Point(63.545406, 54.183765), {3, 6}), (Point(15.675366, 3.084451), {4, 7}), (Point(100.000000, 100.000000), {5, 6})])
# dict_items([(Point(98.288708, 10.593515), {0, 4}), (Point(100.000000, 0.000000), {0, 7}), (Point(43.781524, 89.935670), {1, 2}), (Point(0.000000, 100.000000), {1, 5}), (Point(63.545406, 54.183765), {2, 3}), (Point(74.843715, 20.857048), {3, 4}), (Point(-68.508530, -6.220085), {5, 6}), (Point(168.508530, -6.220085), {6, 7})])
# dict_items([(Point(63.545406, 54.183765), {0, 2}), (Point(43.781524, 89.935670), {0, 1}), (Point(0.000000, 100.000000), {1, 7}), (Point(74.843715, 20.857048), {2, 3}), (Point(98.288708, 10.593515), {3, 4}), (Point(100.000000, 0.000000), {4, 5}), (Point(168.508530, -6.220085), {5, 6}), (Point(50.000000, 199.042710), {6, 7})])
# dict_items([(Point(50.000000, 199.042710), {0, 3}), (Point(74.843715, 20.857048), {0, 2}), (Point(-68.508530, -6.220085), {1, 2}), (Point(43.781524, 89.935670), {1, 3})])
# dict_items([(Point(-68.508530, -6.220085), {0, 1}), (Point(43.781524, 89.935670), {0, 2}), (Point(50.000000, 199.042710), {1, 2})])
# dict_items([(Point(-68.508530, -6.220085), {0, 3}), (Point(100.000000, 0.000000), {0, 1}), (Point(168.508530, -6.220085), {1, 2}), (Point(74.843715, 20.857048), {2, 3})])
# dict_items([(Point(-68.508530, -6.220085), {0, 2}), (Point(74.843715, 20.857048), {0, 1}), (Point(50.000000, 199.042710), {1, 2})])
# dict_items([(Point(-68.508530, -6.220085), {0, 2}), (Point(74.843715, 20.857048), {0, 1}), (Point(168.508530, -6.220085), {1, 2})])
# dict_items([(Point(50.000000, 199.042710), {0, 2}), (Point(-68.508530, -6.220085), {0, 1}), (Point(168.508530, -6.220085), {1, 2})])

# %%
locator

# %% [markdown]
# # Make queries

# %% [markdown]
# ### A valid query point will return the polygon containing it

# %%
valid_query_point = Point.sample_square(100)
located_tile = locator.locate(valid_query_point)

print(valid_query_point)
print(located_tile)

drawing.plot_polygons(random_tiles, 'k-')
drawing.plot_polygon(located_tile, 'ro-')
drawing.plot_point(valid_query_point)
# Out:
# Point(68.018798, 14.675002)
# Triangle([Point(100.000000, 0.000000), Point(59.299273, 32.662803), Point(36.105180, 20.045599)])

# %% [markdown]
# ### A query point outside the tiling will return None

# %%
false_query_point = Point(100 / 2, 100 * 1.1)
located_tile = locator.locate(false_query_point)

drawing.plot_polygons(random_tiles, 'k-')
drawing.plot_polygon(located_tile, 'ro-')
drawing.plot_point(false_query_point)

# %% [markdown]
# # Even more visuals!

# %% [markdown]
# You have the power to even plot the algorithm as it runs!  The layers are saved in "layer%d.png", and the search layers are saved in "search_layer%d.png". Observe the following examples:

# %%
locator = Kirkpatrick(manual_tiles, plot_layers=True)

# %%
valid_query_point = Point.sample_square(10)
tile = locator.locate(valid_query_point, plot_search=True)
drawing.plot_polygons(manual_tiles, 'k-')
drawing.plot_polygon(tile, 'r-')
drawing.plot_point(valid_query_point)

# %% [markdown]
# # Timing

# %% [markdown]
# Verfiying that the query time is logarithmic seems to be quite difficult.  There is a method in polygons to generate  triangular tilings of reasonable size, but the amount of time taken to generate these tilings is *much* greater than the time to construct the Kirkpatrick object, or to locate the point.  Nevertheless, you can try it out yourself.

# %%
data_pts = time_tests(min_pts=100, max_pts=10000, inc=1000)
drawing.plot_points(data_pts)
