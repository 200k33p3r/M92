# %%
import os
import pandas as pd
import tarfile
import gzip

def gunzip(source_filepath, dest_filepath, block_size=65536):
    with gzip.open(source_filepath, 'rb') as s_file, \
            open(dest_filepath, 'wb') as d_file:
        while True:
            block = s_file.read(block_size)
            if not block:
                break
            else:
                d_file.write(block)

# %%
my_tar = tarfile.open('my_tar.tar.gz')
my_tar.extractall('./my_folder') # specify which folder to extract to
my_tar.close()

# %%
test_path = "/data/Catherine/feh230"
extract_path = "/data/extract"
rewrite_path = "/data/rewrite"
for file in os.listdir(test_path):
    if file[-4:] == '.tar':

# %%
test_path = "/data/Catherine/feh230"
extract_path = "/data/extract"
rewrite_path = "/data/rewrite"
for file in os.listdir(test_path):
    if file[-4:] == '.tar' and exists("{}/{}".format(extract_path,file[:-4]))==False and file[-9:-4] != 19925:
        my_tar = tarfile.open("{}/{}".format(test_path,file))
        my_tar.extractall("{}/{}".format(extract_path,file[:-4]))
        my_tar.close()
        os.mkdir("{}/{}".format(rewrite_path,file[:-4]))
        if len(os.listdir("{}/{}".format(extract_path,file[:-4]))) != 21 and len(os.listdir("{}/{}".format(extract_path,file[:-4]))) != 12:
            print(file)
        for gz in os.listdir("{}/{}".format(extract_path,file[:-4])):
            gunzip("{}/{}/{}".format(extract_path,file[:-4],gz),"{}/{}/{}".format(extract_path,file[:-4],gz[:-3]))
            os.remove("{}/{}/{}".format(extract_path,file[:-4],gz))
            f = open("{}/{}/{}".format(extract_path,file[:-4],gz[:-3]), "r")
            w = open("{}/{}/{}".format(rewrite_path,file[:-4],gz[:-3]), "w")
            lines_f = f.readlines()
            lines_w = lines_f
            if lines_w[2] == '\n':
                lines_w[3] = lines_f[3][:7] + '0' + lines_f[3][7:] 
                del lines_w[2]
            w.writelines(lines_w)
            f.close()
            w.close()
# Out:
# mcfeh230.14638.tar
# mcfeh230.19746.tar

# %%
'mcfeh230.19925.tar'[-9:-4]
# Out:
# '19925'

# %%
os.listdir(test_path)
# Out:
# ['mcfeh230.19326.tar',
#  'mcfeh230.14246.tar',
#  'mcfehLOW230.11648.tar',
#  'mcfeh230.18395.tar',
#  'mcfeh230.10995.tar',
#  'mcfehLOW230.10645.tar',
#  'mcfehLOW230.17973.tar',
#  'mcfehLOW230.19568.tar',
#  'mcfeh230.17244.tar',
#  'mcfeh230.11393.tar',
#  'mcfeh230.11789.tar',
#  'mcfehLOW230.13689.tar',
#  'mcfehLOW230.12141.tar',
#  'mcfehLOW230.11148.tar',
#  'mcfeh230.17814.tar',
#  'mcfeh230.13954.tar',
#  'mcfehLOW230.17700.tar',
#  'mcfeh230.15353.tar',
#  'mcfehLOW230.15328.tar',
#  'mcfeh230.14332.tar',
#  'mcfehLOW230.14417.tar',
#  'mcfeh230.18955.tar',
#  'mcfehLOW230.18170.tar',
#  'mcfehLOW230.12999.tar',
#  'mcfehLOW230.15065.tar',
#  'mcfeh230.11919.tar',
#  'mcfehLOW230.10685.tar',
#  'mcfeh230.13024.tar',
#  'mcfeh230.10846.tar',
#  'mcfeh230.14725.tar',
#  'mcfehLOW230.16393.tar',
#  'mcfeh230.10158.tar',
#  'mcfeh230.13328.tar',
#  'mcfeh230.10615.tar',
#  'mcfeh230.17971.tar',
#  'mcfehLOW230.11602.tar',
#  'mcfehLOW230.14398.tar',
#  'mcfeh230.19402.tar',
#  'mcfeh230.15060.tar',
#  'mcfeh230.15054.tar',
#  'mcfeh230.10923.tar',
#  'mcfeh230.14177.tar',
#  'mcfehLOW230.19780.tar',
#  'mcfeh230.18638.tar',
#  'mcfehLOW230.14716.tar',
#  'mcfeh230.13687.tar',
#  'mcfehLOW230.17593.tar',
#  'mcfeh230.15590.tar',
#  'mcfeh230.13388.tar',
#  'mcfeh230.18830.tar',
#  'mcfeh230.19595.tar',
#  'mcfeh230.11151.tar',
#  'mcfehLOW230.19259.tar',
#  'mcfeh230.13203.tar',
#  'mcfeh230.12524.tar',
#  'mcfehLOW230.12836.tar',
#  'mcfeh230.17054.tar',
#  'mcfeh230.16712.tar',
#  'mcfehLOW230.12495.tar',
#  'mcfeh230.18001.tar',
#  'mcfehLOW230.15395.tar',
#  'mcfehLOW230.18841.tar',
#  'mcfeh230.16355.tar',
#  'mcfeh230.15702.tar',
#  'mcfehLOW230.10978.tar',
#  'mcfeh230.17088.tar',
#  'mcfehLOW230.19562.tar',
#  'mcfeh230.14708.tar',
#  'mcfehLOW230.13127.tar',
#  'mcfeh230.16282.tar',
#  'mcfeh230.15315.tar',
#  'mcfehLOW230.16779.tar',
#  'mcfeh230.15357.tar',
#  'mcfeh230.17913.tar',
#  'mcfeh230.15258.tar',
#  'mcfeh230.19373.tar',
#  'mcfeh230.15591.tar',
#  'mcfehLOW230.13397.tar',
#  'mcfehLOW230.12269.tar',
#  'mcfeh230.16865.tar',
#  'mcfehLOW230.16308.tar',
#  'mcfehLOW230.17409.tar',
#  'mcfehLOW230.10036.tar',
#  'mcfehLOW230.16438.tar',
#  'mcfehLOW230.17854.tar',
#  'mcfehLOW230.14324.tar',
#  'mcfehLOW230.17220.tar',
#  'mcfeh230.10859.tar',
#  'mcfehLOW230.14353.tar',
#  'mcfehLOW230.14457.tar',
#  'mcfehLOW230.14138.tar',
#  'mcfeh230.19965.tar',
#  'mcfehLOW230.18015.tar',
#  'mcfehLOW230.13870.tar',
#  'mcfeh230.10722.tar',
#  'mcfeh230.14587.tar',
#  'mcfehLOW230.17965.tar',
#  'mcfehLOW230.13991.tar',
#  'mcfehLOW230.14147.tar',
#  'mcfeh230.13846.tar',
#  'mcfehLOW230.13693.tar',
#  'mcfehLOW230.12967.tar',
#  'mcfehLOW230.17166.tar',
#  'mcfehLOW230.14521.tar',
#  'mcfeh230.11033.tar',
#  'mcfehLOW230.10384.tar',
#  'mcfeh230.12807.tar',
#  'mcfehLOW230.18716.tar',
#  'mcfeh230.10984.tar',
#  'mcfehLOW230.15081.tar',
#  'mcfeh230.19072.tar',
#  'mcfeh230.12322.tar',
#  'mcfeh230.16568.tar',
#  'mcfeh230.13462.tar',
#  'mcfeh230.15551.tar',
#  'mcfehLOW230.14356.tar',
#  'mcfehLOW230.16170.tar',
#  'mcfehLOW230.13433.tar',
#  'mcfehLOW230.17914.tar',
#  'mcfehLOW230.10235.tar',
#  'mcfehLOW230.15755.tar',
#  'mcfehLOW230.11778.tar',
#  'mcfehLOW230.13244.tar',
#  'mcfehLOW230.17900.tar',
#  'mcfeh230.13448.tar',
#  'mcfehLOW230.10315.tar',
#  'mcfeh230.19917.tar',
#  'mcfehLOW230.10363.tar',
#  'mcfehLOW230.16978.tar',
#  'mcfeh230.18828.tar',
#  'mcfeh230.10403.tar',
#  'mcfehLOW230.12934.tar',
#  'mcfeh230.14095.tar',
#  'mcfehLOW230.12563.tar',
#  'mcfehLOW230.11404.tar',
#  'mcfeh230.16366.tar',
#  'mcfehLOW230.15356.tar',
#  'mcfehLOW230.18899.tar',
#  'mcfehLOW230.19757.tar',
#  'mcfeh230.15748.tar',
#  'mcfehLOW230.12728.tar',
#  'mcfehLOW230.18214.tar',
#  'mcfeh230.17145.tar',
#  'mcfeh230.14782.tar',
#  'mcfehLOW230.16885.tar',
#  'mcfeh230.17360.tar',
#  'mcfeh230.18435.tar',
#  'mcfeh230.15439.tar',
#  'mcfeh230.19190.tar',
#  'mcfeh230.12648.tar',
#  'mcfeh230.17746.tar',
#  'mcfehLOW230.13666.tar',
#  'mcfeh230.16890.tar',
#  'mcfeh230.15425.tar',
#  'mcfeh230.12198.tar',
#  'mcfehLOW230.19590.tar',
#  'mcfeh230.12864.tar',
#  'mcfeh230.19474.tar',
#  'mcfeh230.16939.tar',
#  'mcfehLOW230.10261.tar',
#  'mcfeh230.17853.tar',
#  'mcfeh230.14720.tar',
#  'mcfehLOW230.11361.tar',
#  'mcfehLOW230.16363.tar',
#  'mcfeh230.10955.tar',
#  'mcfehLOW230.11802.tar',
#  'mcfeh230.14822.tar',
#  'mcfeh230.18510.tar',
#  'mcfehLOW230.19540.tar',
#  'mcfeh230.18809.tar',
#  'mcfehLOW230.17278.tar',
#  'mcfeh230.15296.tar',
#  'mcfehLOW230.14389.tar',
#  'mcfeh230.16846.tar',
#  'mcfehLOW230.13891.tar',
#  'mcfehLOW230.10586.tar',
#  'mcfehLOW230.11816.tar',
#  'mcfehLOW230.10298.tar',
#  'mcfehLOW230.19075.tar',
#  'mcfeh230.19909.tar',
#  'mcfeh230.18226.tar',
#  'mcfehLOW230.17321.tar',
#  'mcfehLOW230.16224.tar',
#  'mcfeh230.14076.tar',
#  'mcfehLOW230.18786.tar',
#  'mcfeh230.13160.tar',
#  'mcfeh230.10812.tar',
#  'mcfehLOW230.11017.tar',
#  'mcfehLOW230.10447.tar',
#  'mcfeh230.18495.tar',
#  'mcfehLOW230.16550.tar',
#  'mcfeh230.17277.tar',
#  'mcfehLOW230.19163.tar',
#  'mcfehLOW230.12022.tar',
#  'mcfeh230.11605.tar',
#  'mcfehLOW230.18405.tar',
#  'mcfehLOW230.19553.tar',
#  'mcfeh230.18385.tar',
#  'mcfehLOW230.16142.tar',
#  'mcfeh230.11791.tar',
#  'mcfeh230.18821.tar',
#  'mcfeh230.10884.tar',
#  'mcfeh230.14294.tar',
#  'mcfehLOW230.13271.tar',
#  'mcfeh230.17787.tar',
#  'mcfehLOW230.11872.tar',
#  'mcfeh230.19388.tar',
#  'mcfeh230.12181.tar',
#  'mcfeh230.13911.tar',
#  'mcfehLOW230.12811.tar',
#  'mcfehLOW230.10604.tar',
#  'mcfehLOW230.16009.tar',
#  'mcfeh230.14258.tar',
#  'mcfeh230.17011.tar',
#  'mcfeh230.17109.tar',
#  'mcfeh230.13451.tar',
#  'mcfeh230.18498.tar',
#  'mcfeh230.10005.tar',
#  'mcfehLOW230.17265.tar',
#  'mcfeh230.10102.tar',
#  'mcfehLOW230.16577.tar',
#  'mcfehLOW230.19807.tar',
#  'mcfehLOW230.11177.tar',
#  'mcfeh230.13337.tar',
#  'mcfehLOW230.19386.tar',
#  'mcfehLOW230.17237.tar',
#  'mcfeh230.16393.tar',
#  'mcfeh230.11222.tar',
#  'mcfehLOW230.13988.tar',
#  'mcfeh230.18629.tar',
#  'mcfeh230.15679.tar',
#  'mcfeh230.19246.tar',
#  'mcfehLOW230.14641.tar',
#  'mcfeh230.13807.tar',
#  'mcfehLOW230.15656.tar',
#  'mcfeh230.12856.tar',
#  'mcfeh230.11842.tar',
#  'mcfeh230.13210.tar',
#  'mcfehLOW230.19930.tar',
#  'mcfeh230.18426.tar',
#  'mcfeh230.13409.tar',
#  'mcfehLOW230.18638.tar',
#  'mcfehLOW230.14326.tar',
#  'mcfehLOW230.12481.tar',
#  'mcfehLOW230.14151.tar',
#  'mcfehLOW230.17550.tar',
#  'mcfehLOW230.17944.tar',
#  'mcfehLOW230.15509.tar',
#  'mcfehLOW230.14743.tar',
#  'mcfehLOW230.16213.tar',
#  'mcfehLOW230.10050.tar',
#  'mcfeh230.18013.tar',
#  'mcfehLOW230.11920.tar',
#  'mcfeh230.19446.tar',
#  'mcfeh230.14049.tar',
#  'mcfeh230.10948.tar',
#  'mcfehLOW230.16159.tar',
#  'mcfehLOW230.19761.tar',
#  'mcfeh230.10008.tar',
#  'mcfehLOW230.15329.tar',
#  'mcfehLOW230.19057.tar',
#  'mcfeh230.16827.tar',
#  'mcfeh230.17357.tar',
#  'mcfeh230.16963.tar',
#  'mcfeh230.13917.tar',
#  'mcfeh230.17942.tar',
#  'mcfehLOW230.16721.tar',
#  'mcfeh230.17449.tar',
#  'mcfehLOW230.16209.tar',
#  'mcfeh230.17715.tar',
#  'mcfehLOW230.16328.tar',
#  'mcfehLOW230.14661.tar',
#  'mcfeh230.10267.tar',
#  'mcfeh230.18930.tar',
#  'mcfeh230.13219.tar',
#  'mcfehLOW230.12504.tar',
#  'mcfeh230.15023.tar',
#  'mcfeh230.17498.tar',
#  'mcfehLOW230.13884.tar',
#  'mcfeh230.12050.tar',
#  'mcfehLOW230.16657.tar',
#  'mcfehLOW230.19574.tar',
#  'mcfehLOW230.16270.tar',
#  'mcfeh230.12384.tar',
#  'mcfeh230.16315.tar',
#  'mcfeh230.14359.tar',
#  'mcfeh230.16786.tar',
#  'mcfehLOW230.12223.tar',
#  'mcfehLOW230.19481.tar',
#  'mcfeh230.14693.tar',
#  'mcfeh230.17400.tar',
#  'mcfeh230.18588.tar',
#  'mcfeh230.13760.tar',
#  'mcfehLOW230.19237.tar',
#  'mcfeh230.14727.tar',
#  'mcfeh230.12658.tar',
#  'mcfehLOW230.17686.tar',
#  'mcfehLOW230.12076.tar',
#  'mcfehLOW230.15861.tar',
#  'mcfehLOW230.12036.tar',
#  'mcfehLOW230.17485.tar',
#  'mcfehLOW230.14965.tar',
#  'mcfeh230.14175.tar',
#  'mcfehLOW230.19372.tar',
#  'mcfehLOW230.12814.tar',
#  'mcfehLOW230.11986.tar',
#  'mcfehLOW230.14847.tar',
#  'mcfehLOW230.10949.tar',
#  'mcfehLOW230.17388.tar',
#  'mcfehLOW230.14413.tar',
#  'mcfeh230.12989.tar',
#  'mcfehLOW230.13016.tar',
#  'mcfeh230.11761.tar',
#  'mcfeh230.13249.tar',
#  'mcfehLOW230.11392.tar',
#  'mcfehLOW230.10041.tar',
#  'mcfehLOW230.17252.tar',
#  'mcfehLOW230.14299.tar',
#  'mcfehLOW230.18206.tar',
#  'mcfehLOW230.11283.tar',
#  'mcfehLOW230.11568.tar',
#  'mcfehLOW230.16686.tar',
#  'mcfeh230.11107.tar',
#  'mcfehLOW230.12745.tar',
#  'mcfeh230.10454.tar',
#  'mcfeh230.14650.tar',
#  'mcfehLOW230.19463.tar',
#  'mcfeh230.19708.tar',
#  'mcfehLOW230.18389.tar',
#  'mcfeh230.18901.tar',
#  'mcfehLOW230.17581.tar',
#  'mcfehLOW230.15912.tar',
#  'mcfeh230.10389.tar',
#  'mcfeh230.15468.tar',
#  'mcfehLOW230.10899.tar',
#  'mcfehLOW230.13501.tar',
#  'mcfeh230.11629.tar',
#  'mcfehLOW230.10356.tar',
#  'mcfehLOW230.16808.tar',
#  'mcfeh230.18361.tar',
#  'mcfehLOW230.12582.tar',
#  'mcfeh230.18941.tar',
#  'mcfeh230.15015.tar',
#  'mcfehLOW230.15275.tar',
#  'mcfeh230.11513.tar',
#  'mcfehLOW230.19679.tar',
#  'mcfeh230.13457.tar',
#  'mcfeh230.11424.tar',
#  'mcfeh230.13357.tar',
#  'mcfeh230.11989.tar',
#  'mcfeh230.18500.tar',
#  'mcfehLOW230.19438.tar',
#  'mcfeh230.19657.tar',
#  'mcfeh230.17163.tar',
#  'mcfehLOW230.17337.tar',
#  'mcfehLOW230.12944.tar',
#  'mcfehLOW230.17766.tar',
#  'mcfeh230.11145.tar',
#  'mcfehLOW230.11667.tar',
#  'mcfehLOW230.12532.tar',
#  'mcfeh230.13947.tar',
#  'mcfehLOW230.18245.tar',
#  'mcfehLOW230.10552.tar',
#  'mcfehLOW230.16387.tar',
#  'mcfehLOW230.13907.tar',
#  'mcfehLOW230.12876.tar',
#  'mcfeh230.12222.tar',
#  'mcfehLOW230.10452.tar',
#  'mcfeh230.18699.tar',
#  'mcfehLOW230.12082.tar',
#  'mcfehLOW230.18116.tar',
#  'mcfeh230.14828.tar',
#  'mcfehLOW230.15557.tar',
#  'mcfeh230.11634.tar',
#  'mcfehLOW230.17704.tar',
#  'mcfeh230.17485.tar',
#  'mcfehLOW230.17852.tar',
#  'mcfeh230.12599.tar',
#  'mcfeh230.17779.tar',
#  'mcfehLOW230.13173.tar',
#  'mcfeh230.14421.tar',
#  'mcfehLOW230.14610.tar',
#  'mcfeh230.13146.tar',
#  'mcfeh230.13128.tar',
#  'mcfeh230.10869.tar',
#  'mcfehLOW230.17720.tar',
#  'mcfeh230.18875.tar',
#  'mcfehLOW230.16517.tar',
#  'mcfehLOW230.15018.tar',
#  'mcfehLOW230.15545.tar',
#  'mcfeh230.14229.tar',
#  'mcfeh230.18974.tar',
#  'mcfeh230.10932.tar',
#  'mcfehLOW230.12009.tar',
#  'mcfehLOW230.18911.tar',
#  'mcfeh230.15762.tar',
#  'mcfehLOW230.16382.tar',
#  'mcfehLOW230.13278.tar',
#  'mcfehLOW230.14087.tar',
#  'mcfehLOW230.14945.tar',
#  'mcfehLOW230.13328.tar',
#  'mcfehLOW230.19254.tar',
#  'mcfeh230.19528.tar',
#  'mcfeh230.10700.tar',
#  'mcfehLOW230.13681.tar',
#  'mcfeh230.10991.tar',
#  'mcfehLOW230.14766.tar',
#  'mcfeh230.14748.tar',
#  'mcfehLOW230.13528.tar',
#  'mcfehLOW230.17643.tar',
#  'mcfehLOW230.13119.tar',
#  'mcfehLOW230.17554.tar',
#  'mcfehLOW230.18639.tar',
#  'mcfeh230.11692.tar',
#  'mcfeh230.13569.tar',
#  'mcfehLOW230.18492.tar',
#  'mcfehLOW230.10753.tar',
#  'mcfehLOW230.17205.tar',
#  'mcfeh230.13898.tar',
#  'mcfeh230.10498.tar',
#  'mcfeh230.17149.tar',
#  'mcfeh230.17754.tar',
#  'mcfehLOW230.19681.tar',
#  'mcfehLOW230.12093.tar',
#  'mcfeh230.12941.tar',
#  'mcfehLOW230.17165.tar',
#  'mcfeh230.14413.tar',
#  'mcfeh230.19331.tar',
#  'mcfeh230.19844.tar',
#  'mcfehLOW230.14710.tar',
#  'mcfehLOW230.12637.tar',
#  'mcfehLOW230.19356.tar',
#  'mcfeh230.12190.tar',
#  'mcfeh230.15869.tar',
#  'mcfehLOW230.17518.tar',
#  'mcfeh230.12383.tar',
#  'mcfeh230.14869.tar',
#  'mcfehLOW230.16040.tar',
#  'mcfehLOW230.10062.tar',
#  'mcfeh230.19952.tar',
#  'mcfehLOW230.12438.tar',
#  'mcfeh230.16992.tar',
#  'mcfeh230.11412.tar',
#  'mcfeh230.11490.tar',
#  'mcfeh230.12454.tar',
#  'mcfehLOW230.10668.tar',
#  'mcfehLOW230.14560.tar',
#  'mcfehLOW230.11808.tar',
#  'mcfehLOW230.17921.tar',
#  'mcfehLOW230.18680.tar',
#  'mcfeh230.10280.tar',
#  'mcfehLOW230.14471.tar',
#  'mcfehLOW230.19604.tar',
#  'mcfehLOW230.17154.tar',
#  'mcfeh230.18717.tar',
#  'mcfeh230.19112.tar',
#  'mcfehLOW230.13580.tar',
#  'mcfehLOW230.14654.tar',
#  'mcfeh230.18012.tar',
#  'mcfehLOW230.15841.tar',
#  'mcfeh230.16531.tar',
#  'mcfeh230.12995.tar',
#  'mcfeh230.11858.tar',
#  'mcfeh230.18306.tar',
#  'mcfehLOW230.15055.tar',
#  'mcfeh230.15618.tar',
#  'mcfehLOW230.19802.tar',
#  'mcfehLOW230.12769.tar',
#  'mcfeh230.17517.tar',
#  'mcfeh230.14304.tar',
#  'mcfeh230.19394.tar',
#  'mcfeh230.16339.tar',
#  'mcfeh230.16331.tar',
#  'mcfeh230.10896.tar',
#  'mcfeh230.13248.tar',
#  'mcfehLOW230.13211.tar',
#  'mcfehLOW230.13002.tar',
#  'mcfehLOW230.12781.tar',
#  'mcfeh230.17588.tar',
#  'mcfehLOW230.12211.tar',
#  'mcfeh230.10504.tar',
#  'mcfehLOW230.13642.tar',
#  'mcfehLOW230.13188.tar',
#  'mcfeh230.10872.tar',
#  'mcfeh230.19010.tar',
#  'mcfehLOW230.14226.tar',
#  'mcfeh230.16925.tar',
#  'mcfeh230.10792.tar',
#  'mcfeh230.15173.tar',
#  'mcfehLOW230.19162.tar',
#  'mcfehLOW230.16522.tar',
#  'mcfeh230.12592.tar',
#  'mcfehLOW230.18331.tar',
#  'mcfehLOW230.13120.tar',
#  'mcfehLOW230.17521.tar',
#  'mcfehLOW230.18367.tar',
#  'mcfeh230.19790.tar',
#  'mcfeh230.19299.tar',
#  'mcfeh230.12756.tar',
#  'mcfeh230.18278.tar',
#  'mcfehLOW230.18269.tar',
#  'mcfeh230.11198.tar',
#  'mcfeh230.11936.tar',
#  'mcfehLOW230.16602.tar',
#  'mcfeh230.14231.tar',
#  'mcfehLOW230.13360.tar',
#  'mcfeh230.11168.tar',
#  'mcfehLOW230.10253.tar',
#  'mcfehLOW230.18658.tar',
#  'mcfeh230.14344.tar',
#  'mcfeh230.17605.tar',
#  'mcfehLOW230.17681.tar',
#  'mcfeh230.13104.tar',
#  'mcfeh230.11480.tar',
#  'mcfeh230.15907.tar',
#  'mcfehLOW230.13062.tar',
#  'mcfehLOW230.18314.tar',
#  'mcfehLOW230.13582.tar',
#  'mcfehLOW230.13558.tar',
#  'mcfeh230.18647.tar',
#  'mcfehLOW230.16188.tar',
#  'mcfehLOW230.17015.tar',
#  'mcfeh230.19197.tar',
#  'mcfeh230.13159.tar',
#  'mcfeh230.16369.tar',
#  'mcfeh230.17176.tar',
#  'mcfehLOW230.12344.tar',
#  'mcfehLOW230.11391.tar',
#  'mcfeh230.16361.tar',
#  'mcfeh230.17834.tar',
#  'mcfeh230.11793.tar',
#  'mcfeh230.12506.tar',
#  'mcfeh230.17766.tar',
#  'mcfehLOW230.15562.tar',
#  'mcfehLOW230.19907.tar',
#  'mcfehLOW230.15249.tar',
#  'mcfehLOW230.14427.tar',
#  'mcfeh230.12867.tar',
#  'mcfehLOW230.18715.tar',
#  'mcfehLOW230.18656.tar',
#  'mcfehLOW230.17767.tar',
#  'mcfehLOW230.12524.tar',
#  'mcfehLOW230.19846.tar',
#  'mcfeh230.10303.tar',
#  'mcfeh230.12453.tar',
#  'mcfehLOW230.14112.tar',
#  'mcfeh230.18293.tar',
#  'mcfeh230.17795.tar',
#  'moveempty.sh\xa0',
#  'mcfehLOW230.13615.tar',
#  'mcfeh230.16448.tar',
#  'mcfeh230.17019.tar',
#  'mcfehLOW230.11340.tar',
#  'mcfeh230.17912.tar',
#  'mcfehLOW230.15787.tar',
#  'mcfehLOW230.18677.tar',
#  'mcfehLOW230.17907.tar',
#  'mcfehLOW230.18575.tar',
#  'mcfehLOW230.15168.tar',
#  'mcfehLOW230.11722.tar',
#  'mcfeh230.17148.tar',
#  'mcfehLOW230.15726.tar',
#  'mcfeh230.14936.tar',
#  'mcfehLOW230.10875.tar',
#  'mcfehLOW230.12907.tar',
#  'mcfehLOW230.14186.tar',
#  'mcfehLOW230.19068.tar',
#  'mcfehLOW230.10220.tar',
#  'mcfeh230.13466.tar',
#  'mcfehLOW230.14514.tar',
#  'mcfeh230.12758.tar',
#  'mcfeh230.16873.tar',
#  'mcfeh230.15142.tar',
#  'mcfeh230.18149.tar',
#  'mcfehLOW230.14354.tar',
#  'mcfeh230.11288.tar',
#  'mcfeh230.13539.tar',
#  'mcfehLOW230.13130.tar',
#  'mcfehLOW230.18671.tar',
#  'mcfeh230.12499.tar',
#  'mcfeh230.17208.tar',
#  'mcfehLOW230.13983.tar',
#  'mcfeh230.18002.tar',
#  'mcfehLOW230.10874.tar',
#  'mcfehLOW230.14515.tar',
#  'mcfehLOW230.10159.tar',
#  'mcfeh230.11475.tar',
#  'mcfeh230.12932.tar',
#  'mcfeh230.15530.tar',
#  'mcfehLOW230.11240.tar',
#  'mcfehLOW230.14386.tar',
#  'mcfehLOW230.15528.tar',
#  'mcfehLOW230.11106.tar',
#  'mcfehLOW230.18870.tar',
#  'mcfeh230.19472.tar',
#  'mcfehLOW230.17620.tar',
#  'mcfehLOW230.11084.tar',
#  'mcfehLOW230.18130.tar',
#  'mcfehLOW230.18608.tar',
#  'mcfeh230.14104.tar',
#  'mcfehLOW230.15784.tar',
#  'mcfeh230.16586.tar',
#  'mcfehLOW230.12589.tar',
#  'mcfeh230.14902.tar',
#  'mcfehLOW230.11217.tar',
#  'mcfehLOW230.13548.tar',
#  'mcfeh230.16274.tar',
#  'mcfehLOW230.15033.tar',
#  'mcfehLOW230.10893.tar',
#  'mcfeh230.19272.tar',
#  'mcfehLOW230.19773.tar',
#  'mcfeh230.19693.tar',
#  'mcfehLOW230.10348.tar',
#  'mcfehLOW230.19460.tar',
#  'mcfeh230.12017.tar',
#  'mcfehLOW230.19661.tar',
#  'mcfeh230.19303.tar',
#  'mcfehLOW230.10582.tar',
#  'mcfeh230.18675.tar',
#  'mcfehLOW230.14578.tar',
#  'mcfehLOW230.12840.tar',
#  'mcfehLOW230.17194.tar',
#  'mcfehLOW230.15313.tar',
#  'mcfehLOW230.15874.tar',
#  'mcfeh230.11105.tar',
#  'mcfehLOW230.13057.tar',
#  'mcfehLOW230.17132.tar',
#  'mcfehLOW230.11798.tar',
#  'mcfehLOW230.14655.tar',
#  'mcfehLOW230.13942.tar',
#  'mcfehLOW230.14853.tar',
#  'mcfeh230.18117.tar',
#  'mcfeh230.15127.tar',
#  'mcfehLOW230.18462.tar',
#  'mcfeh230.19343.tar',
#  'mcfehLOW230.18661.tar',
#  'mcfehLOW230.17366.tar',
#  'mcfeh230.18403.tar',
#  'mcfehLOW230.10294.tar',
#  'mcfeh230.15703.tar',
#  'mcfehLOW230.15950.tar',
#  'mcfeh230.13968.tar',
#  'mcfehLOW230.10906.tar',
#  'mcfehLOW230.18134.tar',
#  'mcfehLOW230.12774.tar',
#  'mcfeh230.10496.tar',
#  'mcfeh230.18998.tar',
#  'mcfehLOW230.15025.tar',
#  'mcfeh230.15184.tar',
#  'mcfeh230.12468.tar',
#  'mcfehLOW230.11957.tar',
#  'mcfeh230.17276.tar',
#  'mcfeh230.13020.tar',
#  'mcfeh230.15833.tar',
#  'mcfehLOW230.10957.tar',
#  'mcfeh230.17852.tar',
#  'mcfeh230.17301.tar',
#  'mcfehLOW230.18917.tar',
#  'mcfehLOW230.15681.tar',
#  'mcfeh230.17317.tar',
#  'mcfeh230.13606.tar',
#  'mcfehLOW230.10786.tar',
#  'mcfehLOW230.15476.tar',
#  'mcfehLOW230.15266.tar',
#  'mcfeh230.19857.tar',
#  'mcfehLOW230.18914.tar',
#  'mcfehLOW230.12408.tar',
#  'mcfehLOW230.12570.tar',
#  'mcfeh230.19431.tar',
#  'mcfehLOW230.16603.tar',
#  'mcfehLOW230.15182.tar',
#  'mcfehLOW230.14279.tar',
#  'mcfeh230.19663.tar',
#  'mcfeh230.10090.tar',
#  'mcfeh230.15560.tar',
#  'mcfehLOW230.10197.tar',
#  'mcfehLOW230.15179.tar',
#  'mcfehLOW230.19041.tar',
#  'mcfehLOW230.11498.tar',
#  'mcfeh230.13783.tar',
#  'mcfehLOW230.13717.tar',
#  'mcfehLOW230.17051.tar',
#  'mcfeh230.17370.tar',
#  'mcfehLOW230.10785.tar',
#  'mcfeh230.10436.tar',
#  'mcfeh230.14841.tar',
#  'mcfeh230.13838.tar',
#  'mcfeh230.19045.tar',
#  'mcfeh230.12812.tar',
#  'mcfehLOW230.14997.tar',
#  'mcfeh230.18488.tar',
#  'mcfeh230.18698.tar',
#  'mcfeh230.18491.tar',
#  'mcfeh230.17419.tar',
#  'mcfeh230.15923.tar',
#  'mcfeh230.12217.tar',
#  'mcfeh230.16169.tar',
#  'mcfehLOW230.14162.tar',
#  'mcfehLOW230.12115.tar',
#  'mcfeh230.14737.tar',
#  'mcfeh230.12754.tar',
#  'mcfeh230.13446.tar',
#  'mcfehLOW230.15317.tar',
#  'mcfehLOW230.12966.tar',
#  'mcfeh230.17062.tar',
#  'mcfehLOW230.18998.tar',
#  'mcfehLOW230.10085.tar',
#  'mcfeh230.18093.tar',
#  'mcfeh230.17298.tar',
#  'mcfehLOW230.18167.tar',
#  'mcfehLOW230.19881.tar',
#  'mcfeh230.18188.tar',
#  'mcfehLOW230.16078.tar',
#  'mcfeh230.13929.tar',
#  'mcfeh230.13262.tar',
#  'mcfehLOW230.13672.tar',
#  'mcfeh230.16800.tar',
#  'mcfeh230.11690.tar',
#  'mcfehLOW230.14912.tar',
#  'mcfeh230.17200.tar',
#  'mcfehLOW230.17025.tar',
#  'mcfeh230.10255.tar',
#  'mcfehLOW230.16163.tar',
#  'mcfehLOW230.15170.tar',
#  'mcfeh230.11102.tar',
#  'mcfehLOW230.15378.tar',
#  'mcfehLOW230.12819.tar',
#  'mcfehLOW230.15477.tar',
#  'mcfehLOW230.16146.tar',
#  'mcfeh230.16183.tar',
#  'mcfeh230.14730.tar',
#  'mcfehLOW230.15994.tar',
#  'mcfehLOW230.15945.tar',
#  'mcfeh230.16647.tar',
#  'mcfeh230.13428.tar',
#  'mcfehLOW230.14689.tar',
#  'mcfeh230.10185.tar',
#  'mcfeh230.17716.tar',
#  'mcfehLOW230.18685.tar',
#  'mcfeh230.18311.tar',
#  'mcfehLOW230.14564.tar',
#  'mcfeh230.18318.tar',
#  'mcfeh230.14701.tar',
#  'mcfeh230.15406.tar',
#  'mcfehLOW230.18848.tar',
#  'mcfeh230.12318.tar',
#  'mcfehLOW230.17227.tar',
#  'mcfehLOW230.18212.tar',
#  'mcfeh230.12184.tar',
#  'mcfehLOW230.11401.tar',
#  'mcfeh230.18867.tar',
#  'mcfeh230.15914.tar',
#  'mcfehLOW230.10488.tar',
#  'mcfeh230.14818.tar',
#  'mcfehLOW230.10364.tar',
#  'mcfeh230.17422.tar',
#  'mcfeh230.14286.tar',
#  'mcfeh230.18866.tar',
#  'mcfehLOW230.18114.tar',
#  'mcfehLOW230.18259.tar',
#  'mcfehLOW230.11937.tar',
#  'mcfehLOW230.11306.tar',
#  'mcfeh230.19619.tar',
#  'mcfehLOW230.10390.tar',
#  'mcfehLOW230.13960.tar',
#  'mcfehLOW230.11690.tar',
#  'mcfeh230.11777.tar',
#  'mcfehLOW230.12806.tar',
#  'mcfehLOW230.19341.tar',
#  'mcfeh230.15288.tar',
#  'mcfehLOW230.11757.tar',
#  'mcfehLOW230.12616.tar',
#  'mcfeh230.15737.tar',
#  'mcfehLOW230.11997.tar',
#  'mcfeh230.17788.tar',
#  'mcfehLOW230.16023.tar',
#  'mcfeh230.10906.tar',
#  'mcfehLOW230.13239.tar',
#  'mcfeh230.12527.tar',
#  'mcfeh230.10749.tar',
#  'mcfeh230.17637.tar',
#  'mcfehLOW230.17571.tar',
#  'mcfeh230.13276.tar',
#  'mcfeh230.15241.tar',
#  'mcfeh230.17666.tar',
#  'mcfehLOW230.10288.tar',
#  'mcfehLOW230.19500.tar',
#  'mcfehLOW230.17261.tar',
#  'mcfeh230.14993.tar',
#  'mcfeh230.13360.tar',
#  'mcfeh230.18897.tar',
#  'mcfehLOW230.16825.tar',
#  'mcfeh230.14894.tar',
#  'mcfeh230.18882.tar',
#  'mcfehLOW230.18989.tar',
#  'mcfehLOW230.12277.tar',
#  'mcfehLOW230.18246.tar',
#  'mcfehLOW230.19359.tar',
#  'mcfeh230.18785.tar',
#  'mcfeh230.18058.tar',
#  'mcfeh230.18632.tar',
#  'mcfehLOW230.16614.tar',
#  'mcfeh230.19209.tar',
#  'mcfehLOW230.17381.tar',
#  'mcfeh230.10687.tar',
#  'mcfeh230.18072.tar',
#  'mcfeh230.19863.tar',
#  'mcfeh230.17626.tar',
#  'mcfehLOW230.16116.tar',
#  'mcfeh230.18326.tar',
#  'mcfehLOW230.17436.tar',
#  'mcfeh230.15962.tar',
#  'mcfeh230.10778.tar',
#  'mcfehLOW230.12550.tar',
#  'mcfehLOW230.11865.tar',
#  'mcfehLOW230.19265.tar',
#  'mcfehLOW230.14870.tar',
#  'mcfeh230.18508.tar',
#  'mcfeh230.17684.tar',
#  'mcfehLOW230.12405.tar',
#  'mcfehLOW230.16218.tar',
#  'mcfehLOW230.18127.tar',
#  'mcfeh230.17701.tar',
#  'mcfeh230.18683.tar',
#  'mcfehLOW230.16817.tar',
#  'mcfehLOW230.11474.tar',
#  'mcfehLOW230.17296.tar',
#  'mcfeh230.19914.tar',
#  'mcfeh230.17551.tar',
#  'mcfehLOW230.14621.tar',
#  'mcfehLOW230.13074.tar',
#  'mcfehLOW230.18305.tar',
#  'mcfehLOW230.10510.tar',
#  'mcfeh230.12992.tar',
#  'mcfeh230.15372.tar',
#  'mcfeh230.18026.tar',
#  'mcfehLOW230.16668.tar',
#  'mcfehLOW230.10710.tar',
#  'mcfeh230.10212.tar',
#  'mcfehLOW230.19843.tar',
#  'mcfeh230.10831.tar',
#  'mcfeh230.10719.tar',
#  'mcfeh230.16332.tar',
#  'mcfeh230.10143.tar',
#  'mcfehLOW230.16962.tar',
#  'mcfehLOW230.16841.tar',
#  'mcfehLOW230.19027.tar',
#  'mcfeh230.17068.tar',
#  'mcfeh230.10088.tar',
#  'mcfehLOW230.16662.tar',
#  'mcfeh230.18151.tar',
#  'mcfeh230.15244.tar',
#  'mcfehLOW230.16954.tar',
#  'mcfeh230.15890.tar',
#  'mcfehLOW230.19003.tar',
#  'mcfeh230.19930.tar',
#  'mcfeh230.13180.tar',
#  'mcfeh230.17097.tar',
#  'mcfeh230.15323.tar',
#  'mcfehLOW230.10983.tar',
#  'mcfehLOW230.19796.tar',
#  'mcfeh230.16843.tar',
#  'mcfehLOW230.12491.tar',
#  'mcfeh230.12086.tar',
#  'mcfeh230.10414.tar',
#  'mcfeh230.16973.tar',
#  'mcfehLOW230.17293.tar',
#  'mcfehLOW230.12478.tar',
#  'mcfehLOW230.13286.tar',
#  'mcfehLOW230.18166.tar',
#  'mcfehLOW230.16694.tar',
#  'mcfehLOW230.19662.tar',
#  'mcfehLOW230.16444.tar',
#  'mcfeh230.19305.tar',
#  'mcfehLOW230.12725.tar',
#  'mcfeh230.19718.tar',
#  'mcfehLOW230.17149.tar',
#  'mcfehLOW230.11468.tar',
#  'mcfehLOW230.16938.tar',
#  'mcfeh230.16493.tar',
#  'mcfehLOW230.12779.tar',
#  'mcfeh230.14501.tar',
#  'mcfeh230.14308.tar',
#  'mcfeh230.11275.tar',
#  'mcfeh230.10491.tar',
#  'mcfeh230.14068.tar',
#  'mcfehLOW230.15919.tar',
#  'mcfeh230.11172.tar',
#  'mcfehLOW230.13926.tar',
#  'mcfeh230.11741.tar',
#  'mcfehLOW230.11133.tar',
#  'mcfehLOW230.14201.tar',
#  'mcfeh230.17984.tar',
#  'mcfehLOW230.11145.tar',
#  'mcfeh230.10809.tar',
#  'mcfehLOW230.15712.tar',
#  'mcfehLOW230.19754.tar',
#  'mcfehLOW230.12393.tar',
#  'mcfeh230.11900.tar',
#  'mcfeh230.16693.tar',
#  'mcfeh230.16946.tar',
#  'mcfeh230.17156.tar',
#  'mcfehLOW230.18719.tar',
#  'mcfehLOW230.17047.tar',
#  'mcfehLOW230.17201.tar',
#  'mcfeh230.13314.tar',
#  'mcfeh230.16196.tar',
#  'mcfeh230.13786.tar',
#  'mcfehLOW230.19185.tar',
#  'mcfeh230.17675.tar',
#  'mcfeh230.15928.tar',
#  'mcfehLOW230.17546.tar',
#  'mcfeh230.19749.tar',
#  'mcfehLOW230.12156.tar',
#  'mcfehLOW230.15592.tar',
#  'mcfehLOW230.12694.tar',
#  'mcfeh230.17820.tar',
#  'mcfeh230.11018.tar',
#  'mcfehLOW230.14198.tar',
#  'mcfehLOW230.11127.tar',
#  'mcfehLOW230.16671.tar',
#  'mcfehLOW230.14597.tar',
#  'mcfehLOW230.19615.tar',
#  'mcfeh230.11379.tar',
#  'mcfeh230.16610.tar',
#  'mcfeh230.14161.tar',
#  'mcfehLOW230.11529.tar',
#  'mcfehLOW230.19948.tar',
#  'mcfeh230.10392.tar',
#  'mcfehLOW230.14616.tar',
#  'mcfeh230.19525.tar',
#  'mcfeh230.14311.tar',
#  'mcfehLOW230.13778.tar',
#  'mcfeh230.10253.tar',
#  'mcfehLOW230.15005.tar',
#  'mcfeh230.10957.tar',
#  'mcfeh230.15627.tar',
#  'mcfeh230.14540.tar',
#  'mcfeh230.10840.tar',
#  'mcfehLOW230.18741.tar',
#  'mcfeh230.10669.tar',
#  'mcfehLOW230.11364.tar',
#  'mcfehLOW230.16375.tar',
#  'mcfeh230.14905.tar',
#  'mcfeh230.15489.tar',
#  'mcfehLOW230.10074.tar',
#  'mcfehLOW230.19498.tar',
#  'mcfeh230.13029.tar',
#  'mcfehLOW230.16181.tar',
#  'mcfeh230.14769.tar',
#  'mcfehLOW230.15441.tar',
#  'mcfehLOW230.16315.tar',
#  'mcfehLOW230.13416.tar',
#  'mcfehLOW230.18137.tar',
#  'mcfehLOW230.13691.tar',
#  'mcfehLOW230.19808.tar',
#  'mcfehLOW230.12859.tar',
#  'mcfehLOW230.12154.tar',
#  'mcfeh230.16933.tar',
#  'mcfeh230.15037.tar',
#  'mcfehLOW230.17986.tar',
#  'mcfehLOW230.19973.tar',
#  'mcfehLOW230.18412.tar',
#  'mcfehLOW230.14704.tar',
#  'mcfeh230.19633.tar',
#  'mcfehLOW230.19203.tar',
#  'mcfehLOW230.14706.tar',
#  'mcfeh230.14378.tar',
#  'mcfeh230.11098.tar',
#  'mcfeh230.15655.tar',
#  'mcfehLOW230.17814.tar',
#  'mcfeh230.11775.tar',
#  'mcfehLOW230.12911.tar',
#  'mcfeh230.18124.tar',
#  'mcfehLOW230.11326.tar',
#  'mcfeh230.12642.tar',
#  'mcfehLOW230.13630.tar',
#  'mcfehLOW230.18182.tar',
#  'mcfeh230.13952.tar',
#  'mcfehLOW230.17026.tar',
#  'mcfehLOW230.14798.tar',
#  'mcfeh230.14844.tar',
#  'mcfeh230.12355.tar',
#  'mcfehLOW230.17328.tar',
#  'mcfeh230.10142.tar',
#  'mcfeh230.13226.tar',
#  'mcfehLOW230.18614.tar',
#  'mcfeh230.15285.tar',
#  'mcfehLOW230.11236.tar',
#  'mcfehLOW230.18815.tar',
#  'mcfeh230.19052.tar',
#  'mcfeh230.11297.tar',
#  'mcfehLOW230.15150.tar',
#  'mcfehLOW230.10355.tar',
#  'mcfeh230.11651.tar',
#  'mcfeh230.18200.tar',
#  'mcfeh230.14439.tar',
#  'mcfeh230.10024.tar',
#  'mcfehLOW230.19234.tar',
#  'mcfehLOW230.12475.tar',
#  ...]

# %%
from os.path import exists
exists("/data/extract/mcfeh230.10000")
# Out:
# False

# %%
count=0
for file in os.listdir(test_path):
    if file[-4:] == '.tar':
        count += 1
count
# Out:
# 20000

# %%
f = open("/data/extract/mcfeh230.10000/m0500.feh230.10000", "r")
lines = f.readlines()
lines[2]
# Out:
# '\n'

# %%
lines[3]
# Out:
# '# M=0.50 X=7.5382E-01 Z=2.0223E-04 COMP=GS98 [a/Fe]= 0.40 MIXL=2.0215 CCO=0.00\n'

# %%
lines[3][:7] + '0' + lines[3][7:]
# Out:
# '# M=0.500 X=7.5382E-01 Z=2.0223E-04 COMP=GS98 [a/Fe]= 0.40 MIXL=2.0215 CCO=0.00\n'
