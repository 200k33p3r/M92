# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import voronoi_2d_binning
from scipy.spatial import Voronoi, voronoi_plot_2d
import time
plt.matplotlib.rcParams['figure.figsize'] = (15,15)
plt.matplotlib.rcParams['font.size'] = 30

# %%
#Test time to Vorbin 4000000 data points
os.chdir('C:/Users/marti/Desktop/share/testdata_cut')
start = time.time()
dp = pd.read_csv('mc10000.a11000',sep='\s+',names=['vi','v','i'],skiprows=3)
y = dp['v'].values
x = dp['vi'].values*12.5

signal = np.array([1]*len(x))
noise = np.array([1]*len(x))

#vorbin
targetSN = 45
binNum, xNode, yNode, xBar, yBar, sn, nPixels, scale = voronoi_2d_binning.voronoi_2d_binning(
        x, y, signal, noise, targetSN, plot=1, quiet=0)
end = time.time()
print(end - start)
# Out:
# Bin-accretion...
# 1  /  976
# 2  /  976
# 3  /  976
# 4  /  976
# 5  /  976
# 6  /  976
# 7  /  976
# 8  /  976
# 9  /  976
# 10  /  976
# 11  /  976
# 12  /  976
# 13  /  976
# 14  /  976
# 15  /  976
# 16  /  976
# 17  /  976
# 18  /  976
# 19  /  976
# 20  /  976
# 21  /  976
# 22  /  976
# 23  /  976
# 24  /  976
# 25  /  976
# 26  /  976
# 27  /  976
# 28  /  976
# 29  /  976
# 30  /  976
# 31  /  976
# 32  /  976
# 33  /  976
# 34  /  976
# 35  /  976
# 36  /  976
# 37  /  976
# 38  /  976
# 39  /  976
# 40  /  976
# 41  /  976
# 42  /  976
# 43  /  976
# 44  /  976
# 45  /  976
# 46  /  976
# 47  /  976
# 48  /  976
# 49  /  976
# 50  /  976
# 51  /  976
# 52  /  976
# 53  /  976
# 54  /  976
# 55  /  976
# 56  /  976
# 57  /  976
# 58  /  976
# 59  /  976
# 60  /  976
# 61  /  976
# 62  /  976
# 63  /  976
# 64  /  976
# 65  /  976
# 66  /  976
# 67  /  976
# 68  /  976
# 69  /  976
# 70  /  976
# 71  /  976
# 72  /  976
# 73  /  976
# 74  /  976
# 75  /  976
# 76  /  976
# 77  /  976
# 78  /  976
# 79  /  976
# 80  /  976
# 81  /  976
# 82  /  976
# 83  /  976
# 84  /  976
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2520/302384654.py in <module>
#      12 targetSN = 45
#      13 binNum, xNode, yNode, xBar, yBar, sn, nPixels, scale = voronoi_2d_binning.voronoi_2d_binning(
# ---> 14         x, y, signal, noise, targetSN, plot=1, quiet=0)
#      15 end = time.time()
#      16 print(end - start)
#
# ~\Desktop\school work\Dartmouth\M92 project\voronoi_2d_binning.py in voronoi_2d_binning(x, y, signal, noise, targetSN, cvt, pixelsize, plot, quiet, sn_func, wvt)
#     628         print('Bin-accretion...')
#     629     classe, pixelsize = _accretion(
# --> 630         x, y, signal, noise, targetSN, pixelsize, quiet, sn_func)
#     631     if not quiet:
#     632         print(np.max(classe), ' initial bins.')
#
# ~\Desktop\school work\Dartmouth\M92 project\voronoi_2d_binning.py in _accretion(x, y, signal, noise, targetSN, pixelsize, quiet, sn_func)
#     383             #
#     384             unBinned = np.flatnonzero(classe == 0)
# --> 385             k = np.argmin((x[unBinned] - xBar)**2 + (y[unBinned] - yBar)**2)
#     386
#     387             # (1) Find the distance from the closest pixel to the current bin
#
# KeyboardInterrupt:
