# %%
from os import path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import voronoi_2d_binning
plt.matplotlib.rcParams['figure.figsize'] = (15,15)
plt.matplotlib.rcParams['font.size'] = 30

# %%
file_dir = path.dirname(path.realpath(vorbin.__file__))  # path of vorbin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30012/4096633439.py in <module>
# ----> 1 file_dir = path.dirname(path.realpath(vorbin.__file__))  # path of vorbin
#
# NameError: name 'vorbin' is not defined

# %%
dp = pd.read_csv('m92data.csv', dtype=np.float64)
y = dp['V'].values[:140000]
x = dp['VI'].values[:140000]
signal = dp['signal'].values[:140000]
noise = dp['noise'].values[:140000]

# %%
x, y, signal, noise
# Out:
# (array([0.441, 0.   , 0.915, ..., 0.326, 1.356, 1.733]),
#  array([18.874, 15.616, 13.975, ..., 24.129, 26.871, 26.123]),
#  array([1., 1., 1., ..., 1., 1., 1.]),
#  array([1., 1., 1., ..., 1., 1., 1.]))

# %%
targetSN = 100

# %%
binNum, xNode, yNode, xBar, yBar, sn, nPixels, scale = voronoi_2d_binning.voronoi_2d_binning(
        x, y, signal, noise, targetSN, plot=1, quiet=0)
# Out:
# Bin-accretion...
# 1  /  14
# 2  /  14
# 3  /  14
# 4  /  14
# 5  /  14
# 6  /  14
# 7  /  14
# 8  /  14
# 9  /  14
# 10  /  14
# 11  /  14
# 12  /  14
# 13  /  14
# 14  /  14
# 14  initial bins.
# Reassign bad bins...
# 14  good bins.
# Modified Lloyd algorithm...
# Iter:    1  Diff: 0.3873
# Iter:    2  Diff: 0.4432
# Iter:    3  Diff: 0.5351
# Iter:    4  Diff: 0.5644
# Iter:    5  Diff: 0.441
# Iter:    6  Diff: 0.3345
# Iter:    7  Diff: 0.2622
# Iter:    8  Diff: 0.2362
# Iter:    9  Diff: 0.2229
# Iter:   10  Diff: 0.2147
# Iter:   11  Diff: 0.2154
# Iter:   12  Diff: 0.2134
# Iter:   13  Diff: 0.2116
# 12  iterations.
# Unbinned pixels:  0  /  140000
# Fractional S/N scatter (%): 32.72114083905717
# Elapsed time accretion: 208.26 seconds
# Elapsed time optimization: 22.66 seconds

# %%
np.savetxt('voronoi_2d_binning_result_SN50_711.txt', np.column_stack([x, y, binNum]),
               fmt=b'%10.6f %10.6f %8i')

# %%
targetSN = 50

# %%
binNum, xNode, yNode, xBar, yBar, sn, nPixels, scale = voronoi_2d_binning.voronoi_2d_binning(
        x, y, signal, noise, targetSN, plot=1, quiet=0)
# Out:
# Bin-accretion...
# 1  /  56
# 2  /  56
# 3  /  56
# 4  /  56
# 5  /  56
# 6  /  56
# 7  /  56
# 8  /  56
# 9  /  56
# 10  /  56
# 11  /  56
# 12  /  56
# 13  /  56
# 14  /  56
# 15  /  56
# 16  /  56
# 17  /  56
# 18  /  56
# 19  /  56
# 20  /  56
# 21  /  56
# 22  /  56
# 23  /  56
# 24  /  56
# 25  /  56
# 26  /  56
# 27  /  56
# 28  /  56
# 29  /  56
# 30  /  56
# 31  /  56
# 32  /  56
# 33  /  56
# 34  /  56
# 35  /  56
# 36  /  56
# 37  /  56
# 38  /  56
# 39  /  56
# 40  /  56
# 41  /  56
# 42  /  56
# 43  /  56
# 44  /  56
# 45  /  56
# 46  /  56
# 47  /  56
# 48  /  56
# 49  /  56
# 50  /  56
# 51  /  56
# 52  /  56
# 53  /  56
# 54  /  56
# 55  /  56
# 56  /  56
# 56  initial bins.
# Reassign bad bins...
# 55  good bins.
# Modified Lloyd algorithm...
# Iter:    1  Diff: 0.8876
# Iter:    2  Diff: 0.573
# Iter:    3  Diff: 0.4483
# Iter:    4  Diff: 0.3898
# Iter:    5  Diff: 0.3498
# Iter:    6  Diff: 0.3284
# Iter:    7  Diff: 0.31
# Iter:    8  Diff: 0.3028
# ...

# %%
np.savetxt('voronoi_2d_binning_result_test.txt', np.column_stack([x, y, binNum]),
               fmt=b'%10.6f %10.6f %8i')

# %%
targetSN = 20
binNum, xNode, yNode, xBar, yBar, sn, nPixels, scale = voronoi_2d_binning.voronoi_2d_binning(
        x, y, signal, noise, targetSN, plot=1, quiet=0)
# Out:
# Bin-accretion...
# 1  /  350
# 2  /  350
# 3  /  350
# 4  /  350
# 5  /  350
# 6  /  350
# 7  /  350
# 8  /  350
# 9  /  350
# 10  /  350
# 11  /  350
# 12  /  350
# 13  /  350
# 14  /  350
# 15  /  350
# 16  /  350
# 17  /  350
# 18  /  350
# 19  /  350
# 20  /  350
# 21  /  350
# 22  /  350
# 23  /  350
# 24  /  350
# 25  /  350
# 26  /  350
# 27  /  350
# 28  /  350
# 29  /  350
# 30  /  350
# 31  /  350
# 32  /  350
# 33  /  350
# 34  /  350
# 35  /  350
# 36  /  350
# 37  /  350
# 38  /  350
# 39  /  350
# 40  /  350
# 41  /  350
# 42  /  350
# 43  /  350
# 44  /  350
# 45  /  350
# 46  /  350
# 47  /  350
# 48  /  350
# 49  /  350
# 50  /  350
# 51  /  350
# 52  /  350
# 53  /  350
# 54  /  350
# 55  /  350
# 56  /  350
# 57  /  350
# 58  /  350
# 59  /  350
# 60  /  350
# 61  /  350
# 62  /  350
# 63  /  350
# 64  /  350
# 65  /  350
# 66  /  350
# 67  /  350
# 68  /  350
# 69  /  350
# 70  /  350
# 71  /  350
# 72  /  350
# 73  /  350
# 74  /  350
# 75  /  350
# 76  /  350
# ...

# %%
targetSN = 10
binNum, xNode, yNode, xBar, yBar, sn, nPixels, scale = voronoi_2d_binning.voronoi_2d_binning(
        x, y, signal, noise, targetSN, plot=1, quiet=0)
# Out:
# Bin-accretion...
# 1  /  1400
# 2  /  1400
# 3  /  1400
# 4  /  1400
# 5  /  1400
# 6  /  1400
# 7  /  1400
# 8  /  1400
# 9  /  1400
# 10  /  1400
# 11  /  1400
# 12  /  1400
# 13  /  1400
# 14  /  1400
# 15  /  1400
# 16  /  1400
# 17  /  1400
# 18  /  1400
# 19  /  1400
# 20  /  1400
# 21  /  1400
# 22  /  1400
# 23  /  1400
# 24  /  1400
# 25  /  1400
# 26  /  1400
# 27  /  1400
# 28  /  1400
# 29  /  1400
# 30  /  1400
# 31  /  1400
# 32  /  1400
# 33  /  1400
# 34  /  1400
# 35  /  1400
# 36  /  1400
# 37  /  1400
# 38  /  1400
# 39  /  1400
# 40  /  1400
# 41  /  1400
# 42  /  1400
# 43  /  1400
# 44  /  1400
# 45  /  1400
# 46  /  1400
# 47  /  1400
# 48  /  1400
# 49  /  1400
# 50  /  1400
# 51  /  1400
# 52  /  1400
# 53  /  1400
# 54  /  1400
# 55  /  1400
# 56  /  1400
# 57  /  1400
# 58  /  1400
# 59  /  1400
# 60  /  1400
# 61  /  1400
# 62  /  1400
# 63  /  1400
# 64  /  1400
# 65  /  1400
# 66  /  1400
# 67  /  1400
# 68  /  1400
# 69  /  1400
# 70  /  1400
# ...

# %%
plt.matplotlib.rcParams['figure.figsize'] = (15,15)
plt.matplotlib.rcParams['font.size'] = 30
def _display_pixels(x, y, counts, pixelsize):
    """
    Display pixels at coordinates (x, y) coloured with "counts".
    This routine is fast but not fully general as it assumes the spaxels
    are on a regular grid. This needs not be the case for Voronoi binning.

    """
    xmin, xmax = np.min(x), np.max(x)
    ymin, ymax = np.min(y), np.max(y)
    nx = int(round((xmax - xmin)/pixelsize) + 1)
    ny = int(round((ymax - ymin)/pixelsize) + 1)
    img = np.full((nx, ny), np.nan)  # use nan for missing data
    j = np.round((x - xmin)/pixelsize).astype(int)
    k = np.round((y - ymin)/pixelsize).astype(int)
    img[j, k] = counts

    plt.imshow(np.rot90(img), interpolation='nearest', cmap='prism',
               extent=[xmin - pixelsize/2, xmax + pixelsize/2,
                       ymin - pixelsize/2, ymax + pixelsize/2])
plt.clf()
plt.subplot(211)
rnd = np.argsort(np.random.random(xNode.size))  # Randomize bin colors
_display_pixels(x, y, rnd[binNum], 1)
plt.plot(xNode, yNode, '+w', scalex=False, scaley=False) # do not rescale after imshow()
plt.xlabel('F606W - F814W')
plt.ylabel('F606W')
plt.title('Map of Voronoi bins')
# Out:
# Text(0.5, 1.0, 'Map of Voronoi bins')

# %%
plt.subplot(212)
single = 1
rad = np.sqrt(xBar**2 + yBar**2)  # Use centroids, NOT generators
plt.plot(np.sqrt(x**2 + y**2), signal/noise, ',k')
#if np.any(single):
#    plt.plot(rad[single], sn[single], 'xb', label='Not binned')
plt.plot(rad, sn, 'or',alpha=0.1, label='Voronoi bins')
plt.xlabel('Distance from center')
plt.ylabel('Bin S/N')
plt.axis([np.min(rad), np.max(rad), 0, np.max(sn)*1.05])  # x0, x1, y0, y1
plt.axhline(targetSN)
plt.legend()
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
# !python voronoi_2d_binning_example.py

# %%
plt.tight_layout()

# %%
plt

# %%
# !python voronoi_2d_binning_example.py

# %%
voronoi_2d_binning(
        x, y, signal, noise, targetSN, plot=1, quiet=0)

# %%
np.loadtxt('voronoi_2d_binning_result_SN50.txt')

# %%
np.zeros((3,2,2))[2]

# %%
targetSN = 200

# %%
binNum, xNode, yNode, xBar, yBar, sn, nPixels, scale = voronoi_2d_binning.voronoi_2d_binning(
        x, y, signal, noise, targetSN, plot=1, quiet=0)

# %%
np.savetxt('voronoi_2d_binning_result_SN200.txt', np.column_stack([x, y, binNum]),
               fmt=b'%10.6f %10.6f %8i')

# %%
plt.scatter(x,y,s=1)

# %%
dp = pd.read_csv('M92_fits.csv', dtype=np.float64)
y = dp['V'].values
x = dp['VI'].values*16
signal = dp['signal'].values
noise = dp['noise'].values

# %%
x, y, signal, noise
# Out:
# (array([10.52799987, 10.54399966, 10.64000034, ...,  8.44799995,
#          8.09599971,  8.06400013]),
#  array([15.9259996, 15.927    , 15.927    , ..., 19.9249992, 19.9249992,
#         19.9249992]),
#  array([1., 1., 1., ..., 1., 1., 1.]),
#  array([1., 1., 1., ..., 1., 1., 1.]))

# %%
targetSN = 5

# %%
binNum, xNode, yNode, xBar, yBar, sn, nPixels, scale = voronoi_2d_binning.voronoi_2d_binning(
        x, y, signal, noise, targetSN, plot=1, quiet=0)
# Out:
# Bin-accretion...
# 1  /  723
# 2  /  723
# 3  /  723
# 4  /  723
# 5  /  723
# 6  /  723
# 7  /  723
# 8  /  723
# 9  /  723
# 10  /  723
# 11  /  723
# 12  /  723
# 13  /  723
# 14  /  723
# 15  /  723
# 16  /  723
# 17  /  723
# 18  /  723
# 19  /  723
# 20  /  723
# 21  /  723
# 22  /  723
# 23  /  723
# 24  /  723
# 25  /  723
# 26  /  723
# 27  /  723
# 28  /  723
# 29  /  723
# 30  /  723
# 31  /  723
# 32  /  723
# 33  /  723
# 34  /  723
# 35  /  723
# 36  /  723
# 37  /  723
# 38  /  723
# 39  /  723
# 40  /  723
# 41  /  723
# 42  /  723
# 43  /  723
# 44  /  723
# 45  /  723
# 46  /  723
# 47  /  723
# 48  /  723
# 49  /  723
# 50  /  723
# 51  /  723
# 52  /  723
# 53  /  723
# 54  /  723
# 55  /  723
# 56  /  723
# 57  /  723
# 58  /  723
# 59  /  723
# 60  /  723
# 61  /  723
# 62  /  723
# 63  /  723
# 64  /  723
# 65  /  723
# 66  /  723
# 67  /  723
# 68  /  723
# 69  /  723
# 70  /  723
# 71  /  723
# 72  /  723
# 73  /  723
# 74  /  723
# 75  /  723
# 76  /  723
# ...

# %%
def _display_pixels(x, y, counts, pixelsize):
    """
    Display pixels at coordinates (x, y) coloured with "counts".
    This routine is fast but not fully general as it assumes the spaxels
    are on a regular grid. This needs not be the case for Voronoi binning.

    """
    xmin, xmax = np.min(x), np.max(x)
    ymin, ymax = np.min(y), np.max(y)
    nx = int(round((xmax - xmin)/pixelsize) + 1)
    ny = int(round((ymax - ymin)/pixelsize) + 1)
    img = np.full((nx, ny), np.nan)  # use nan for missing data
    j = np.round((x - xmin)/pixelsize).astype(int)
    k = np.round((y - ymin)/pixelsize).astype(int)
    img[j, k] = counts

    plt.imshow(np.rot90(img), interpolation='nearest', cmap='prism',
               extent=[xmin - pixelsize/2, xmax + pixelsize/2,
                       ymin - pixelsize/2, ymax + pixelsize/2])
plt.clf()
plt.subplot(211)
rnd = np.argsort(np.random.random(xNode.size))  # Randomize bin colors
_display_pixels(x, y, rnd[binNum], 1)
plt.plot(xNode, yNode, '+w', scalex=False, scaley=False) # do not rescale after imshow()
plt.xlabel('F606W - F814W')
plt.ylabel('F606W')
plt.title('Map of Voronoi bins')
# Out:
# Text(0.5, 1.0, 'Map of Voronoi bins')

# %%
np.savetxt('voronoi_2d_binning_result_SN5.txt', np.column_stack([x/12, y, binNum]),
               fmt=b'%10.6f %10.6f %8i')

# %%
dp = pd.read_csv('voronoi_2d_binning_result_SN5.txt', sep ='\s+',names = ['V', 'VI', 'bin'])
dp
# Out:
#               V         VI  bin
# 0      0.877333  15.926000    0
# 1      0.878667  15.927000    0
# 2      0.886667  15.927000    0
# 3      0.881333  15.931000    0
# 4      0.909333  15.932000    0
# ...         ...        ...  ...
# 18072  0.694667  19.924999  704
# 18073  0.681333  19.924999  689
# 18074  0.704000  19.924999  707
# 18075  0.674667  19.924999  683
# 18076  0.672000  19.924999  677
#
# [18077 rows x 3 columns]

# %%
plt.matplotlib.rcParams['figure.figsize'] = (15,15)
plt.matplotlib.rcParams['font.size'] = 30
import random
bin = 0
cmap = []
j = 0
for i in range(len(dp)):
    if bin == dp['bin'].values[i]:
        cmap.append(list(mcolors.CSS4_COLORS.keys())[j])
    else:
        bin += 1
        if j < 147:
            j += 1
            cmap.append(list(mcolors.CSS4_COLORS.keys())[j])
        else:
            j = 0
            cmap.append(list(mcolors.CSS4_COLORS.keys())[j])

plt.scatter(dp['V'].values,dp['VI'].values,c=cmap,s=5)

# %%
points=dp[['V','VI']].to_numpy()

# %%
from scipy.spatial import Voronoi, voronoi_plot_2d
vor = Voronoi(points)
fig = voronoi_plot_2d(vor)
plt.show()

# %%
xBar
# Out:
# array([8.00762265, 8.51200008, 7.76040002, 7.41599997, 7.86937498,
#        7.70559998, 7.86514285, 7.5592    , 7.64519997, 7.04520006,
#        7.40307691, 8.07999993, 8.4840002 , 7.6789333 , 7.47516276,
#        7.67873673, 7.29792008, 7.51033338, 7.85435297, 7.4109999 ,
#        7.70999992, 7.53400004, 7.29541465, 7.15309102, 7.43383786,
#        6.8700001 , 7.37257137, 7.222     , 6.9992728 , 7.2761143 ,
#        7.07250005, 7.41659993, 7.16737497, 7.22400002, 6.93035295,
#        7.03907692, 6.56879997, 7.01799998, 6.89836363, 6.90066663,
#        6.61542862, 6.76628571, 6.42327267, 6.71623537, 6.63692302,
#        6.54514284, 6.57446812, 6.43567748, 6.51600004, 6.30141184,
#        6.33648   , 6.29999995, 6.153     , 6.03999996, 6.20378182,
#        6.10493623, 6.25599996, 6.02223534, 6.02964718, 5.928     ,
#        5.87400001, 5.9413091 , 5.91663162, 5.86254544, 5.85250909,
#        5.77927269, 5.73709085, 5.78167742, 5.76635292, 5.89920001,
# ...

# %%
points = np.stack((xBar/16, yBar), axis=1)
vor = Voronoi(points)
fig = voronoi_plot_2d(vor)
plt.show()

# %%
points = np.stack((xBar, yBar), axis=1)
vor = Voronoi(points)
fig = voronoi_plot_2d(vor)
plt.show()

# %%
points = np.stack((xBar, yBar), axis=1)
vor = Voronoi(points)
fig = voronoi_plot_2d(vor)
plt.show()

# %%
points = np.stack((xBar, yBar), axis=1)
vor = Voronoi(points)
fig = voronoi_plot_2d(vor,show_vertices=False,show_points=False)
plt.scatter(dp['VI'].values*16,dp['V'].values,s=1)
plt.show()

# %%
plt.scatter(dp['VI'].values,dp['V'].values,s=1)

# %%
x = vor.ridge_points[:,0]
y = vor.ridge_points[:,1]

# %%
points = np.stack((xBar, yBar), axis=1)
vor = Voronoi(points)
fig = voronoi_plot_2d(vor,show_vertices=False,show_points=False)
plt.scatter(x,y)
plt.xlim(5.5,11.5)
plt.ylim(15.8,20.2)
plt.show()

# %%
vor.regions
# Out:
# [[],
#  [5, 1, -1, 4],
#  [7, 3, -1, 1, 2, 6],
#  [11, 8, 4, -1, 0, 10],
#  [27, 12, 9, 14, 18, 26],
#  [31, 18, 14, 13, 24, 25, 30],
#  [34, 12, 9, 3, 7, 33],
#  [35, 28, 27, 12, 34],
#  [38, 21, 20, 8, 4, 5, 37],
#  [57, 55, 54, 56],
#  [57, 37, 5, 1, 2, 36, 56],
#  [61, 55, 57, 37, 38, 60],
#  [63, 58, 59, 39, 19, 17, 16, 62],
#  [69, 66, 65, 64, 67, 68],
#  [67, 36, 56, 54, 64],
#  [65, 61, 55, 54, 64],
#  [68, 62, 16, 15, 6, 2, 36, 67],
#  [80, 45, 44, 43, 78, 75, 79],
#  [86, 40, 22, 11, 8, 20, 42, 85],
#  [97, 94, 24, 25, 96],
#  [102, 15, 16, 17, 46, 47, 101],
#  [103, 33, 7, 6, 15, 102],
#  [107, 100, 46, 47, 105],
#  [113, 109, 111, 110, 112],
#  [112, 13, 24, 94, 110],
#  [113, 70, 92, 91, 0, -1, 3, 9, 14, 13, 112],
#  [118, 76, 87, 86, 40, 117],
#  [128, 63, 62, 68, 69, 127],
#  [141, 116, 117, 40, 22, 140],
#  [150, 120, 119, 41, 149],
#  [151, 108, 73, 121, 120, 150],
#  [153, 51, 50, 49, 52, 152],
#  [154, 53, 48, 51, 153],
#  [156, 71, 109, 113, 70, 90, 89, 155],
# ...

# %%
vor.vertices
# Out:
# array([[-8.88178420e-15,  1.01908318e+03],
#        [ 1.10134124e-13, -9.83027032e+02],
#        [-7.63352873e+01, -9.07094214e+02],
#        ...,
#        [ 6.92665055e+00,  1.92704661e+01],
#        [ 7.04123823e+00,  1.92175056e+01],
#        [ 7.02181162e+00,  1.92146194e+01]])

# %%
def voronoi_finite_polygons_2d(vor, radius=None):
    """
    Reconstruct infinite voronoi regions in a 2D diagram to finite
    regions.

    Parameters
    ----------
    vor : Voronoi
        Input diagram
    radius : float, optional
        Distance to 'points at infinity'.

    Returns
    -------
    regions : list of tuples
        Indices of vertices in each revised Voronoi regions.
    vertices : list of tuples
        Coordinates for revised Voronoi vertices. Same as coordinates
        of input vertices, with 'points at infinity' appended to the
        end.

    """

    if vor.points.shape[1] != 2:
        raise ValueError("Requires 2D input")

    new_regions = []
    new_vertices = vor.vertices.tolist()

    center = vor.points.mean(axis=0)
    if radius is None:
        radius = vor.points.ptp().max()

    # Construct a map containing all ridges for a given point
    all_ridges = {}
    for (p1, p2), (v1, v2) in zip(vor.ridge_points, vor.ridge_vertices):
        all_ridges.setdefault(p1, []).append((p2, v1, v2))
        all_ridges.setdefault(p2, []).append((p1, v1, v2))

    # Reconstruct infinite regions
    for p1, region in enumerate(vor.point_region):
        vertices = vor.regions[region]

        if all(v >= 0 for v in vertices):
            # finite region
            new_regions.append(vertices)
            continue

        # reconstruct a non-finite region
        ridges = all_ridges[p1]
        new_region = [v for v in vertices if v >= 0]

        for p2, v1, v2 in ridges:
            if v2 < 0:
                v1, v2 = v2, v1
            if v1 >= 0:
                # finite ridge: already in the region
                continue

            # Compute the missing endpoint of an infinite ridge

            t = vor.points[p2] - vor.points[p1] # tangent
            t /= np.linalg.norm(t)
            n = np.array([-t[1], t[0]])  # normal

            midpoint = vor.points[[p1, p2]].mean(axis=0)
            direction = np.sign(np.dot(midpoint - center, n)) * n
            far_point = vor.vertices[v2] + direction * radius

            new_region.append(len(new_vertices))
            new_vertices.append(far_point.tolist())

        # sort region counterclockwise
        vs = np.asarray([new_vertices[v] for v in new_region])
        c = vs.mean(axis=0)
        angles = np.arctan2(vs[:,1] - c[1], vs[:,0] - c[0])
        new_region = np.array(new_region)[np.argsort(angles)]

        # finish
        new_regions.append(new_region.tolist())

    return new_regions, np.asarray(new_vertices)

# %%
regions, vertices = voronoi_finite_polygons_2d(vor)
# colorize
for region in regions:
    polygon = vertices[region]
    plt.fill(*zip(*polygon), alpha=0.4)

#plt.plot(points[:,0], points[:,1], 'ko')
plt.xlim(vor.min_bound[0] - 0.1, vor.max_bound[0] + 0.1)
plt.ylim(vor.min_bound[1] - 0.1, vor.max_bound[1] + 0.1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3704/4287806755.py in <module>
# ----> 1 regions, vertices = voronoi_finite_polygons_2d(vor)
#       2 # colorize
#       3 for region in regions:
#       4     polygon = vertices[region]
#       5     plt.fill(*zip(*polygon), "r")
#
# NameError: name 'voronoi_finite_polygons_2d' is not defined

# %%
regions
# Out:
# [[21, 988, 987, 20, 28, 27],
#  [20, 990, 989, 0, 9],
#  [41, 27, 21, 40],
#  [188, 187, 992, 991, 21, 40, 38, 22],
#  [48, 42, 41, 27, 28, 47],
#  [42, 39, 38, 40, 41],
#  [47, 28, 20, 9, 46],
#  [48, 42, 39, 25, 44],
#  [48, 44, 43, 45, 46, 47],
#  [39, 25, 26, 23, 22, 38],
#  [261, 188, 22, 23, 8, 7, 19, 259],
#  [91, 24, 43, 44, 25, 26, 90],
#  [46, 9, 0, 1, 2, 45],
#  [90, 26, 23, 8, 55, 89],
#  [119, 91, 24, 10, 118],
#  [45, 2, 10, 24, 43],
#  [142, 119, 91, 90, 89, 141],
#  [147, 118, 119, 142],
#  [143, 57, 56, 55, 89, 141],
#  [56, 54, 7, 8, 55],
#  [147, 142, 141, 143, 145, 144, 146],
#  [147, 118, 10, 2, 1, 5, 146],
#  [146, 5, 6, 111, 112, 76, 75, 144],
#  [145, 33, 51, 57, 143],
#  [145, 33, 77, 75, 144],
#  [57, 51, 53, 52, 54, 56],
#  [78, 53, 51, 33, 77],
#  [105, 74, 52, 54, 7, 19, 104],
#  [79, 74, 52, 53, 78],
#  [80, 76, 75, 77, 78, 79],
#  [200, 105, 74, 79, 80, 199],
#  [206, 112, 76, 80, 199, 197, 134, 106, 205],
#  [200, 105, 104, 135, 198],
# ...

# %%
vertices
# Out:
# array([[16.21809544, 21.49330282],
#        [11.52758834, 19.27731898],
#        [10.57363593, 17.8403802 ],
#        ...,
#        [ 9.16823624, 64.38469234],
#        [ 5.38199655, 17.747347  ],
#        [ 5.07676392, 19.16605607]])

# %%
manual_tiles = []
for i in range(len(regions)):
    points = []
    for j in range(len(regions[i])):
        points.append(Point(vertices[regions[i][j]][0],vertices[regions[i][j]][1]))
    manual_tiles.append(Polygon(points))
drawing.plot_polygons(manual_tiles, 'k-')
#plt.xlim(5.5,11.5)
#plt.ylim(15.8,20.2);

# %%
def search_point_location(x, y, xBar, yBar):
    delta_x = [xbar - x for xbar in xBar]
    delta_y = [ybar - y for ybar in yBar]
    distance = (np.square(delta_x) + np.square(delta_y)).tolist()
    min_value = min(distance)
    bin_num = distance.index(min_value)
    return bin_num

# %%
search_point_location(8, 18, xBar, yBar)
# Out:
# 57

# %%
points = np.stack((xBar, yBar), axis=1)
vor = Voronoi(points)
fig = voronoi_plot_2d(vor,show_vertices=False,show_points=False)
plt.scatter(8,18,s=5,c='Red')
for i in range(len(binNum)):
    if binNum[i] == 57:
        plt.scatter(x[i],y[i],s=5,c='blue')
plt.xlim(5.5,11.5)
plt.ylim(15.8,20.2)
plt.show()

# %%
import time
x = np.random.uniform(5.5, 11.5, size=10000)
y = np.random.uniform(15.8, 20.2, size=10000)
start_time = time.time()
for i in range(len(x)):
    search_point_location(x[i], y[i], xBar, yBar)
end_time = time.time()
print(end_time - start_time)
# Out:
# 2.9874484539031982

# %%
import time
x = np.random.uniform(5.5, 11.5, size=1000000)
y = np.random.uniform(15.8, 20.2, size=1000000)
start_time = time.time()
for i in range(len(x)):
    search_point_location(x[i], y[i], xBar, yBar)
end_time = time.time()
print(end_time - start_time)
# Out:
# 295.7217869758606
